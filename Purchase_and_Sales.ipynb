# %%
# Purchase made by customer

import json
import random

fd = open("Available.json",'r')
r = fd.read()
fd.close()
records = json.loads(r)

print(records)
print("Select from the menu and give order accordingly.")
print("If you purchase more than 5 products than you will get a discount coupon worth 5% to 10%")
ui_prod  = str(input("Enter the product_Id: "))
ui_quant = int(input("Enter the quantity: "))
rand=0
if(ui_quant>records[ui_prod]['qn']):
  print("The Quantity of ",records[ui_prod]['name']," is not enough according to your request")
  print("If you want we can give you",records[ui_prod]['qn'],"for now")
  print("For purchasing enter 1 for denying the transaction enter 0")
  choise = int(input("Enter your choise: "))
  if choise!=1:
    pass
  else:
    ui_quant1 =records[ui_prod]['qn']
    if(ui_quant1>=5):
      rand = random.randrange(5,11)
    print("\n")
    print("         _______________________________")
    print("        |                               |")
    print("        |         $$ Invoice $$         |    ")
    print("        |_______________________________|\n")
    print("* * * * * * * * * * * * * * * * * * * * * * * * *")
    print("* * * * * * * * * * * * * * * * * * * * * * * * *")
    print("\n         Product          : ", records[ui_prod]['name'])
    print("         Price            : ", records[ui_prod]['pr'])
    print("         Quantity         : ", ui_quant)
    print("         Discount         : ", str(rand)+"%")
    amount=records[ui_prod]['pr'] * ui_quant1
    print("         Billing Amount   : ", amount)
    print("\n         Total Amount after Taxes and Disscount : ")
    print("         ==>>          ",(amount-(amount*rand)/100), "\n")
    print("* * * * * * * * * * * * * * * * * * * * * * * * *")
    print("* * * * * * * * * * * * * * * * * * * * * * * * *")
    print("\nThank You for Purchasing from Our Bakery\n")
    records[ui_prod]['qn'] = records[ui_prod]['qn'] - ui_quant1

    fd = open("sales.json",'r')
    r1 = fd.read()
    fd.close()
    total_sale = json.loads(r1)
    current_time = datetime.now(timezone("Asia/Kolkata")).strftime('%Y-%m-%d %H:%M:%S')
    total_sale[str(len(total_sale)+1)] = {'amount': records[ui_prod]['pr'] * ui_quant, 'qn' : ui_quant, 'prod' : ui_prod,'Date': current_time}

    ts = json.dumps(total_sale)
    fd = open("sales.json",'w')
    fd.write(ts)
    fd.close()

else:
  if(ui_quant>=5):
    rand = random.randrange(5,11)
  print("\n")
  print("         _______________________________")
  print("        |                               |")
  print("        |         $$ Invoice $$         |    ")
  print("        |_______________________________|\n")
  print("* * * * * * * * * * * * * * * * * * * * * * * * *")
  print("* * * * * * * * * * * * * * * * * * * * * * * * *")
  print("\n         Product          : ", records[ui_prod]['name'])
  print("         Price            : ", records[ui_prod]['pr'])
  print("         Quantity         : ", ui_quant)
  print("         Discount         : ", str(rand)+"%")
  amount=records[ui_prod]['pr'] * ui_quant
  print("         Billing Amount   : ", amount)
  print("\n         Total Amount after Taxes and Disscount : ")
  print("         ==>>          ",(amount-(amount*rand)/100), "\n")
  print("* * * * * * * * * * * * * * * * * * * * * * * * *")
  print("* * * * * * * * * * * * * * * * * * * * * * * * *")
  print("\nThank You for Purchasing from Our Bakery\n")
  records[ui_prod]['qn'] = records[ui_prod]['qn'] - ui_quant

  
  # Sales Record ==>>
  from pytz import timezone
  from datetime import datetime

  fd = open("sales.json",'r')
  r1 = fd.read()
  fd.close()
  total_sale = json.loads(r1)
  current_time = datetime.now(timezone("Asia/Kolkata")).strftime('%Y-%m-%d %H:%M:%S')
  total_sale[str(len(total_sale)+1)] = {'amount': records[ui_prod]['pr'] * ui_quant, 'qn' : ui_quant, 'prod' : ui_prod,'Date': current_time}

  ts = json.dumps(total_sale)
  fd = open("sales.json",'w')
  fd.write(ts)
  fd.close()

js = json.dumps(records)

fd = open("Available.json",'w')
fd.write(js)
fd.close()
# Out:
# {'1001': {'name': 'Vanila Cake', 'pr': 150, 'qn': 0, 'category': 'Cake'}, '1002': {'name': 'Chocolate Cake', 'pr': 250, 'qn': 19, 'category': 'Cake'}, '1003': {'name': 'strawberry Cake', 'pr': 300, 'qn': 25, 'category': 'Cake'}, '1004': {'name': 'Milk Cake', 'pr': 200, 'qn': 35, 'category': 'Cake'}, '1005': {'name': 'Cheese Pizza', 'pr': 275, 'qn': 15, 'category': 'Pizza'}, '1006': {'name': 'Vege Pizza', 'pr': 180, 'qn': 15, 'category': 'Pizza'}, '1007': {'name': 'Pattis', 'pr': 80, 'qn': 30, 'category': 'Snack'}, '1008': {'name': 'Cheese Cake', 'pr': 500, 'qn': 15, 'category': 'Cake'}, '1009': {'name': 'Cupcakes', 'pr': 70, 'qn': 50, 'category': 'Dessert'}, '1010': {'name': 'Brownie', 'pr': 200, 'qn': 70, 'category': 'Dessert'}, '1011': {'name': 'Donut', 'pr': 50, 'qn': 70, 'category': 'Dessert'}, '1012': {'name': 'Strawberry Pastry', 'pr': 50, 'qn': 40, 'category': 'Dessert'}, '1013': {'name': 'Mousse', 'pr': 110, 'qn': 30, 'category': 'Dessert'}, '1014': {'name': 'Burger', 'pr': 55, 'qn': 40, 'category': 'Fast Food'}, '1015': {'name': 'Cheese Sandwich', 'pr': 110, 'qn': 25, 'category': 'Fast Food'}, '1016': {'name': 'Vege Sandwich', 'pr': 80, 'qn': 25, 'category': 'Fast Food'}, '1017': {'name': 'Garlic Bread', 'pr': 150, 'qn': 15, 'category': 'Fast Food'}, '1018': {'name': 'Brown Bread', 'pr': 40, 'qn': 20, 'category': 'Dairy'}, '1019': {'name': 'Vanilla Ice-Cream', 'pr': 45, 'qn': 15, 'category': 'Dairy'}, '1020': {'name': 'Chocolate Ice-Cream', 'pr': 55, 'qn': 15, 'category': 'Dairy'}, '1021': {'name': 'Coco Powder', 'pr': 120, 'qn': 18, 'category': 'Dairy'}, '1022': {'name': 'Milk Powder', 'pr': 120, 'qn': 30, 'category': 'Dairy'}, '1023': {'name': 'Strawberry Ice-Cream', 'pr': 70, 'qn': 20, 'category': 'Dairy'}, '1024': {'name': 'Candy', 'pr': 15, 'qn': 60, 'category': 'Dairy'}, '1025': {'name': 'Popsicle', 'pr': 20, 'qn': 60, 'category': 'Dairy'}, '1026': {'name': 'Chocobar', 'pr': 35, 'qn': 20, 'category': 'Dairy'}, '1027': {'name': 'Dolly', 'pr': 15, 'qn': 30, 'category': 'Dairy'}, '1028': {'name': 'Choco Lava', 'pr': 45, 'qn': 20, 'category': 'Dessert'}, '1029': {'name': 'Hot Dog', 'pr': 35, 'qn': 25, 'category': 'Fast Food'}, '1030': {'name': 'Buiscuit', 'pr': 25, 'qn': 60, 'category': 'Dessert'}}
# Select from the menu and give order accordingly.
# If you purchase more than 5 products than you will get a discount coupon worth 5% to 10%
# Enter the product_Id: 1002
# Enter the quantity: 1
#
#
#          _______________________________
#         |                               |
#         |         $$ Invoice $$         |
#         |_______________________________|
#
# * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * *
#
#          Product          :  Chocolate Cake
#          Price            :  250
#          Quantity         :  1
#          Discount         :  0%
#          Billing Amount   :  250
#
#          Total Amount after Taxes and Disscount :
#          ==>>           250.0
#
# * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * *
#
# Thank You for Purchasing from Our Bakery
